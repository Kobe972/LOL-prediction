# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
def player_data_classifier(attr,reverse=0):
    main_data=pd.read_csv('data.csv')
    subtable_kill=main_data['player1_'+attr]+main_data['player2_'+attr]+main_data['player3_'+attr]+main_data['player4_'+attr]+main_data['player5_'+attr]
    subtable_kill.name='player_'+attr
    subtable=DataFrame([main_data['team1_win'],subtable_kill])
    subtable=subtable.stack().unstack(0)
    subtable.index.name='index'
    m=min(subtable_kill)
    M=max(subtable_kill)
    max_accuracy=0
    max_i=m
    def no(x):
        if(x==0):
            return 1
        else:
            return 0
    for i in range(m,M+1):
        cross_entropy=0
        tmp1=subtable['player_'+attr]>=i
        tmp2=subtable['player_'+attr]<i
        u=subtable['team1_win'][tmp1]
        v=subtable['team1_win'][tmp2]
        if(reverse==0):
            accuracy=(u.sum()+v.apply(no).sum())/len(subtable.index)
        else:
            accuracy=(v.sum()+u.apply(no).sum())/len(subtable.index)
        if accuracy>max_accuracy:
            max_accuracy=accuracy
            max_i=i
    print('max_accuracy=',max_accuracy)
    print('corresponding classifier i=',max_i)
    tmp=subtable[subtable['player_'+attr]>=max_i]['team1_win'].value_counts()
    if(reverse==0):
        tmp.index=['team1_win','team1_loss']
    else:
        tmp.index=['team1_loss','team1_win']
    plt.title('player_'+attr+'>='+str(max_i))
    tmp.plot(kind='barh')
    plt.show()
    print('player_'+attr+'>=',max_i,'对应的玩家胜负情况统计')
    print(tmp)
    tmp=subtable[subtable['player_'+attr]<max_i]['team1_win'].value_counts()
    if(reverse==0):
        tmp.index=['team1_loss','team1_win']
    else:
        tmp.index=['team1_win','team1_loss']
    plt.title('player_'+attr+'<'+str(max_i))
    tmp.plot(kind='barh')
    plt.show()
    print('player_'+attr+'<',max_i,'对应的玩家胜负情况统计')
    print(tmp)
player_data_classifier('kills',0)
# Out:
# max_accuracy= 0.723
# corresponding classifier i= 24
# player_kills>= 24 对应的玩家胜负情况统计
# team1_win     29339
# team1_loss    12974
# Name: team1_win, dtype: int64
# player_kills< 24 对应的玩家胜负情况统计
# team1_loss    28501
# team1_win      9186
# Name: team1_win, dtype: int64

# %%
player_data_classifier('deaths',1)
# Out:
# max_accuracy= 0.73835
# corresponding classifier i= 22
# player_deaths>= 22 对应的玩家胜负情况统计
# team1_loss    34561
# team1_win     14018
# Name: team1_win, dtype: int64
# player_deaths< 22 对应的玩家胜负情况统计
# team1_win     24507
# team1_loss     6914
# Name: team1_win, dtype: int64

# %%
player_data_classifier('assists',0)
# Out:
# max_accuracy= 0.69495
# corresponding classifier i= 36
# player_assists>= 36 对应的玩家胜负情况统计
# team1_win     26425
# team1_loss    12304
# Name: team1_win, dtype: int64
# player_assists< 36 对应的玩家胜负情况统计
# team1_loss    29171
# team1_win     12100
# Name: team1_win, dtype: int64

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
def player_data_classifier(attr,reverse=0):
    main_data=pd.read_csv('data.csv')
    subtable_kill=main_data['player1_'+attr]
    subtable_kill.name='player_'+attr
    subtable=DataFrame([main_data['team1_win'],subtable_kill])
    subtable=subtable.stack().unstack(0)
    subtable.index.name='index'
    m=min(subtable_kill)
    M=max(subtable_kill)
    max_accuracy=0
    max_i=m
    def no(x):
        if(x==0):
            return 1
        else:
            return 0
    for i in range(m,M+1):
        cross_entropy=0
        tmp1=subtable['player_'+attr]>=i
        tmp2=subtable['player_'+attr]<i
        u=subtable['team1_win'][tmp1]
        v=subtable['team1_win'][tmp2]
        if(reverse==0):
            accuracy=(u.sum()+v.apply(no).sum())/len(subtable.index)
        else:
            accuracy=(v.sum()+u.apply(no).sum())/len(subtable.index)
        if accuracy>max_accuracy:
            max_accuracy=accuracy
            max_i=i
    print('max_accuracy=',max_accuracy)
    print('corresponding classifier i=',max_i)
    tmp=subtable[subtable['player_'+attr]>=max_i]['team1_win'].value_counts()
    if(reverse==0):
        tmp.index=['team1_win','team1_loss']
    else:
        tmp.index=['team1_loss','team1_win']
    plt.title('player_'+attr+'>='+str(max_i))
    tmp.plot(kind='barh')
    plt.show()
    print('player_'+attr+'>=',max_i,'对应的玩家胜负情况统计')
    print(tmp)
    tmp=subtable[subtable['player_'+attr]<max_i]['team1_win'].value_counts()
    if(reverse==0):
        tmp.index=['team1_loss','team1_win']
    else:
        tmp.index=['team1_win','team1_loss']
    plt.title('player_'+attr+'<'+str(max_i))
    tmp.plot(kind='barh')
    plt.show()
    print('player_'+attr+'<',max_i,'对应的玩家胜负情况统计')
    print(tmp)
player_data_classifier('goldEarned',0)
# Out:
# max_accuracy= 0.5985
# corresponding classifier i= 10105
# player_goldEarned>= 10105 对应的玩家胜负情况统计
# team1_win     21921
# team1_loss    15516
# Name: team1_win, dtype: int64
# player_goldEarned< 10105 对应的玩家胜负情况统计
# team1_loss    25959
# team1_win     16604
# Name: team1_win, dtype: int64

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
def win_to_team_data(data_name):
    class1=main_data['team1_win'][main_data[data_name]]
    class2=main_data['team1_win'][-main_data[data_name]]
    result=DataFrame([class1.value_counts(),class2.value_counts()],index=[data_name,'!'+data_name])
    result.columns.name='team1_win'
    result['sum']=[result.loc[data_name].sum(),result.loc['!'+data_name].sum()]
    print(result)
    p1=float(result[0][data_name])/result['sum'][data_name]
    p2=float(result[0]['!'+data_name])/result['sum']['!'+data_name]
    entropy1=-p1*math.log2(p1)-(1-p1)*math.log2(1-p1)
    entropy2=-p2*math.log2(p2)-(1-p2)*math.log2(1-p2)
    print('weighted entropy=',entropy1*result['sum'][data_name]/result['sum'].sum()+entropy2*result['sum']['!'+data_name]/result['sum'].sum())
    print('weighted accuracy=',(1-p1)*result['sum'][data_name]/result['sum'].sum()+p2*result['sum']['!'+data_name]/result['sum'].sum())
    result2=result.drop(columns=['sum'])
    result2.plot(kind='barh',)
    plt.savefig('results\\histogram.png',bbox_inches='tight')
    plt.show()
    
win_to_team_data('team1_firstBlood')
# Out:
# team1_win              0      1    sum
# team1_firstBlood   17210  23363  40573
# !team1_firstBlood  24265  15162  39427
# weighted entropy= 0.9724306992699958
# weighted accuracy= 0.5953499999999999

# %%
win_to_team_data('team1_firstTower')
# Out:
# team1_win              0      1    sum
# team1_firstTower   11829  27661  39490
# !team1_firstTower  29646  10864  40510
# weighted entropy= 0.8595204061747612
# weighted accuracy= 0.7163375000000001

# %%
win_to_team_data('team1_firstInhibitor')
# Out:
# team1_win                  0      1    sum
# team1_firstInhibitor    2849  27336  30185
# !team1_firstInhibitor  38626  11189  49815
# weighted entropy= 0.6486788709672755
# weighted accuracy= 0.824525

# %%
win_to_team_data('team1_firstBaron')
# Out:
# team1_win              0      1    sum
# team1_firstBaron    3978  18381  22359
# !team1_firstBaron  37497  20144  57641
# weighted entropy= 0.8614604995846399
# weighted accuracy= 0.698475

# %%
win_to_team_data('team1_firstDragon')
# Out:
# team1_win               0      1    sum
# team1_firstDragon   14451  23259  37710
# !team1_firstDragon  27024  15266  42290
# weighted entropy= 0.9514081023720498
# weighted accuracy= 0.6285375

# %%
win_to_team_data('team1_firstRiftHerald')
# Out:
# team1_win                   0      1    sum
# team1_firstRiftHerald   14747  22065  36812
# !team1_firstRiftHerald  26728  16460  43188
# weighted entropy= 0.9645703422299919
# weighted accuracy= 0.6099125000000001

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player1_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player1_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player2_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player2_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player3_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player3_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player4_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player4_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player5_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player5_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player1_championId'].value_counts()+main_data['player2_championId'].value_counts()+main_data['player3_championId'].value_counts()+main_data['player4_championId'].value_counts()+main_data['player5_championId'].value_counts()+main_data['player6_championId'].value_counts()+main_data['player7_championId'].value_counts()+main_data['player8_championId'].value_counts()+main_data['player9_championId'].value_counts()+main_data['player10_championId'].value_counts()
subtable=subtable.sort_index(ascending=True)
subtable=subtable[:45]
fig, ax = plt.subplots()
plt.title('player1~10_championId')
subtable.plot(kind='bar')
ax.set_xticks(np.arange(min(subtable.index),max(subtable.index),5))
plt.xlim(min(subtable.index),max(subtable.index))
plt.xlabel('ID')
plt.ylabel('count')
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data[np.array(main_data['player1_championId']==21)|np.array(main_data['player2_championId']==21)|np.array(main_data['player3_championId']==21)|np.array(main_data['player4_championId']==21)|np.array(main_data['player5_championId']==21)]
win=subtable['team1_win'].sum()
loss=len(subtable.index)-win
result=DataFrame([win,loss],index=['win','loss'])
print('result:')
print(result)
print('accuracy:',loss/(win+loss))
result.plot(kind='barh')
plt.show()
# Out:
# result:
#          0
# win   2854
# loss  2875
# accuracy: 0.5018327805899808

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data['player1_role'].value_counts()+main_data['player2_role'].value_counts()+main_data['player3_role'].value_counts()+main_data['player4_role'].value_counts()+main_data['player5_role'].value_counts()+main_data['player6_role'].value_counts()+main_data['player7_role'].value_counts()+main_data['player8_role'].value_counts()+main_data['player9_role'].value_counts()+main_data['player10_role'].value_counts()
fig, ax = plt.subplots()
plt.title('roles')
subtable.plot(kind='bar')
plt.show()

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import numpy as np
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
subtable=main_data[np.array(main_data['player1_role']=='DUO_SUPPORT')|np.array(main_data['player2_role']=='DUO_SUPPORT')|np.array(main_data['player3_role']=='DUO_SUPPORT')|np.array(main_data['player4_role']=='DUO_SUPPORT')|np.array(main_data['player5_role']=='DUO_SUPPORT')]
win=subtable['team1_win'].sum()
loss=len(subtable.index)-win
result=DataFrame([win,loss],index=['win','loss'])
print('result:')
print(result)
print('accuracy:',loss/(win+loss))
result.plot(kind='barh')
plt.show()
# Out:
# result:
#           0
# win   36704
# loss  39576
# accuracy: 0.5188253801782905

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
def win_to_team_data(data_name1,data_name2):
    class1=main_data[data_name2][main_data[data_name1]]
    class2=main_data[data_name2][-main_data[data_name1]]
    result=DataFrame([class1.value_counts(),class2.value_counts()],index=[data_name1,'!'+data_name1])
    result.columns.name=data_name2
    result['sum']=[result.loc[data_name1].sum(),result.loc['!'+data_name1].sum()]
    print(result)
    p1=float(result[0][data_name1])/result['sum'][data_name1]
    p2=float(result[0]['!'+data_name1])/result['sum']['!'+data_name1]
    entropy1=-p1*math.log2(p1)-(1-p1)*math.log2(1-p1)
    entropy2=-p2*math.log2(p2)-(1-p2)*math.log2(1-p2)
    print('weighted entropy=',entropy1*result['sum'][data_name1]/result['sum'].sum()+entropy2*result['sum']['!'+data_name1]/result['sum'].sum())
    print('weighted accuracy=',(1-p1)*result['sum'][data_name1]/result['sum'].sum()+p2*result['sum']['!'+data_name1]/result['sum'].sum())
    result2=result.drop(columns=['sum'])
    result2.plot(kind='barh',)
    plt.show()

names=['team1_firstBlood','team1_firstTower','team1_firstInhibitor','team1_firstBaron','team1_firstDragon','team1_firstRiftHerald']
for i in range(0,len(names)-1):
    for j in range(i+1,len(names)):
        win_to_team_data(names[i],names[j])
# Out:
# team1_firstTower    True  False    sum
# team1_firstBlood   24281  16292  40573
# !team1_firstBlood  15209  24218  39427
# weighted entropy= 0.9669962447627047
# weighted accuracy= 0.6062375
# team1_firstInhibitor  False   True    sum
# team1_firstBlood      22568  18005  40573
# !team1_firstBlood     27247  12180  39427
# weighted entropy= 0.9421015876006011
# weighted accuracy= 0.56565
# team1_firstBaron   False   True    sum
# team1_firstBlood   27849  12724  40573
# !team1_firstBlood  29792   9635  39427
# weighted entropy= 0.8504485432418589
# weighted accuracy= 0.53145
# team1_firstDragon   True  False    sum
# team1_firstBlood   21893  18680  40573
# !team1_firstBlood  15817  23610  39427
# weighted entropy= 0.9837225020176562
# weighted accuracy= 0.5687875
# team1_firstRiftHerald   True  False    sum
# team1_firstBlood       21196  19377  40573
# !team1_firstBlood      15616  23811  39427
# weighted entropy= 0.9837930240057176
# weighted accuracy= 0.5625875
# ...

# %%
from pandas import Series,DataFrame
import pandas as pd
import math
import matplotlib.pyplot as plt
main_data=pd.read_csv('data.csv')
main_data=main_data['team1_win'].value_counts()
main_data.plot(kind='barh',)
print('win_data',main_data[1])
print('loss_data',main_data[0])
plt.show()
# Out:
# win_data 38525
# loss_data 41475
